# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/malehamajid/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# **Refresh / Content Opportunity Scoring**
#
# I chose this lane because it focuses on identifying which pages should be reviewed first for content refresh using search and engagement signals. This is a practical decision-support problem, and the starter dataset already includes the features needed to explore it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question
#
# **Decision:** Decide which pages should be reviewed first for content refresh.
#
# **Action:** The SEO or content team can review and update the highest-priority pages.
#
# **Cost of a Wrong Recommendation:** If the recommendation is wrong, the team may spend time updating low-impact pages while important declining pages are missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import json

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

results = json.load(open("outputs/model_results.json"))

print("Baseline Precision@50:", results["baseline"]["baseline_precision_at_50"])
print("Random Forest Precision@50:", results["models"]["random_forest"]["precision_at_50"])

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains 30,000 pages with 44 features. The baseline achieved a Precision@50 of 0.24, while the Random Forest model achieved 0.74 on the starter dataset. These results suggest that combining multiple search and engagement signals may improve page prioritization compared with a simple rule.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project provides decision-support based on observed search and engagement signals. The results may suggest which pages should be reviewed first, but they do not prove that refreshing a page will increase traffic or reveal how Google's ranking algorithm works. Any recommendations should be reviewed by humans before action is taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
